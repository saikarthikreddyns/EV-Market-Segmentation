# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df_cars=pd.read_excel("Indian EV Cars.xlsx")
df_cars.drop(columns=['Unnamed: 0'],inplace=True)
df_cars['Brand']=df_cars['Name'].apply(lambda x:x.split(' ')[0])
org_cars=df_cars.copy()

# %%
df_cars
# Out:
#                    Name Fuel Type  Driving Range (km)  Seating Capacity  \
# 0         Tata Punch EV  Electric                 315                 5
# 1           MG Comet EV  Electric                 230                 4
# 2         Tata Nexon EV  Electric                 325                 5
# 3         Tata Tiago EV  Electric                 250                 5
# 4              BYD Seal  Electric                 510                 5
# 5       Mahindra XUV400  Electric                 375                 5
# 6        Audi e-tron GT  Electric                 388                 5
# 7         Jaguar I-Pace  Electric                 470                 5
# 8               Kia EV6  Electric                 708                 5
# 9       Hyundai Ioniq 5  Electric                 631                 5
# 10           BYD Atto 3  Electric                 521                 5
# 11  Volvo XC40 Recharge  Electric                 475                 5
# ...

# %%
df_cars.isnull().sum()
# Out:
# Name                           0
# Fuel Type                      0
# Driving Range (km)             0
# Seating Capacity               0
# NCAP Rating (Best - 5 Star)    0
# Battery Capacity               0
# Size                           0
# Ground Clearance (mm)          0
# Avg. Waiting Period (Days)     0
# Top End Price (₹)              0
# Top Speed                      0
# Warranty (Years)               0
# Warranty (Km)                  0
# Battery Warrenty (yr)          0
# Battery Warranty (km)          0
# Brand                          0
# dtype: int64

# %%
df_cars['Brand'] = df_cars['Brand'].astype('category').cat.codes
df_cars['Name'] = df_cars['Name'].astype('category').cat.codes
df_cars['Fuel Type']=df_cars['Fuel Type'].astype('category').cat.codes

# %%
df_cars
# Out:
#     Name  Fuel Type  Driving Range (km)  Seating Capacity  \
# 0     16          0                 315                 5
# 1      9          0                 230                 4
# 2     15          0                 325                 5
# 3     17          0                 250                 5
# 4      4          0                 510                 5
# 5     12          0                 375                 5
# 6      0          0                 388                 5
# 7      7          0                 470                 5
# 8      8          0                 708                 5
# 9      6          0                 631                 5
# 10     3          0                 521                 5
# 11    19          0                 475                 5
# 12     5          0                 415                 5
# 13    10          0                 461                 5
# 14     2          0                 625                 5
# ...

# %%
#Can drop fuel type column as doesnt show any variation among it
df_cars.drop(columns=['Fuel Type'],inplace=True)

# %%
df_cars.dtypes
# Out:
# Name                              int8
# Driving Range (km)               int64
# Seating Capacity                 int64
# NCAP Rating (Best - 5 Star)      int64
# Battery Capacity               float64
# Size                             int64
# Ground Clearance (mm)            int64
# Avg. Waiting Period (Days)       int64
# Top End Price (₹)                int64
# Top Speed                        int64
# Warranty (Years)                 int64
# Warranty (Km)                    int64
# Battery Warrenty (yr)            int64
# Battery Warranty (km)            int64
# Brand                             int8
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_cars is your DataFrame

# Determine the number of rows and columns for subplots
num_cols = 2
num_rows = (len(df_cars.columns) + 1) // num_cols

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 20))

# Flatten axes for easy iteration
axes = axes.flatten()

# Iterate over columns and plot
for i, col in enumerate(df_cars.columns):
    ax = axes[i]
    sns.kdeplot(df_cars[col], ax=ax)
    ax.set_xlabel(col)

plt.tight_layout()
plt.show()

# %%
org_cars['Brand'].value_counts().plot(kind='bar',color='skyblue')
plt.title('Brand Distribution')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Top End Price (₹)',palette='husl')
plt.title("Top prices of brands")
# Out:
# Text(0.5, 1.0, 'Top prices of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Driving Range (km)',palette='husl')
plt.title("Top riding range of brands")
# Out:
# Text(0.5, 1.0, 'Top riding range of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Seating Capacity',palette='husl')
plt.title("Seating capacity of brands")
# Out:
# Text(0.5, 1.0, 'Seating capacity of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Battery Capacity',palette='husl')
plt.title("Battery capacity of brands")
# Out:
# Text(0.5, 1.0, 'Battery capacity of brands')

# %%
org_cars.groupby('Brand')['Size'].mean().plot(kind='bar',color='red')
plt.ylabel("Mean Size")
plt.title("Average size of brands")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Ground Clearance (mm)',palette='husl')
plt.title("Ground clearance of brands")
# Out:
# Text(0.5, 1.0, 'Ground clearance of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Avg. Waiting Period (Days)',palette='husl')
plt.title("Avg. Waiting Period (Days) of brands")
# Out:
# Text(0.5, 1.0, 'Avg. Waiting Period (Days) of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Top Speed',palette='husl')
plt.title("Top Speed of brands")
# Out:
# Text(0.5, 1.0, 'Top Speed of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Warranty (Years)',palette='husl')
plt.title("Warranty (Years) of brands")
# Out:
# Text(0.5, 1.0, 'Warranty (Years) of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Warranty (Km)',palette='husl')
plt.title("Warranty (km) of brands")
# Out:
# Text(0.5, 1.0, 'Warranty (km) of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Battery Warrenty (yr)',palette='husl')
plt.title("Battery Warranty (year) of brands")
# Out:
# Text(0.5, 1.0, 'Battery Warranty (year) of brands')

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=org_cars,x='Brand',y='Battery Warranty (km)',palette='husl')
plt.title("Battery Warranty (km) of brands")
# Out:
# Text(0.5, 1.0, 'Battery Warranty (km) of brands')

# %%
plt.figure(figsize=(10,10),dpi=120)
sns.heatmap(df_cars.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_cars.skew()
# Out:
# Name                           0.000000
# Driving Range (km)             0.165801
# Seating Capacity              -2.123060
# NCAP Rating (Best - 5 Star)   -0.784528
# Battery Capacity              -0.277311
# Size                          -0.628279
# Ground Clearance (mm)         -0.113442
# Avg. Waiting Period (Days)     1.467389
# Top End Price (₹)              3.745546
# Top Speed                     -0.054686
# Warranty (Years)               1.330134
# Warranty (Km)                  0.520009
# Battery Warrenty (yr)          4.472136
# Battery Warranty (km)          3.794067
# Brand                          0.055404
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cars)

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhoute_scores=[]
for i in range(2, 11):
    kmeans = KMeans(n_clusters = i, random_state = 50)
    kmeans.fit(X_scaled)
    silhoute_scores.append(silhouette_score(df_cars,kmeans.labels_))

# %%
silhoute_scores
# Out:
# [0.42295196717950984,
#  0.1175202335490049,
#  -0.06616738790581358,
#  -0.13104671360437628,
#  -0.12741060716998528,
#  -0.21076745623811935,
#  -0.30166694194514376,
#  -0.36152787344972914,
#  -0.3152427692279466]

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(X_scaled)
org_cars["Labels"]=kmeans.labels_

# %%
org_cars
# Out:
#                    Name Fuel Type  Driving Range (km)  Seating Capacity  \
# 0         Tata Punch EV  Electric                 315                 5
# 1           MG Comet EV  Electric                 230                 4
# 2         Tata Nexon EV  Electric                 325                 5
# 3         Tata Tiago EV  Electric                 250                 5
# 4              BYD Seal  Electric                 510                 5
# 5       Mahindra XUV400  Electric                 375                 5
# 6        Audi e-tron GT  Electric                 388                 5
# 7         Jaguar I-Pace  Electric                 470                 5
# 8               Kia EV6  Electric                 708                 5
# 9       Hyundai Ioniq 5  Electric                 631                 5
# 10           BYD Atto 3  Electric                 521                 5
# 11  Volvo XC40 Recharge  Electric                 475                 5
# ...

# %%
sns.scatterplot(data=org_cars,x='Driving Range (km)',y='Top End Price (₹)',c=org_cars['Labels'])
plt.title("Cluster plot")
# Out:
# Text(0.5, 1.0, 'Cluster plot')

# %%
sns.scatterplot(data=org_cars,x='Seating Capacity',y='Size',c=org_cars['Labels'])
plt.title("Cluster plot")
# Out:
# Text(0.5, 1.0, 'Cluster plot')

# %%
sns.scatterplot(data=org_cars,x='Driving Range (km)',y='Top Speed',c=org_cars['Labels'])
plt.title("Cluster plot")
# Out:
# Text(0.5, 1.0, 'Cluster plot')

# %%
sns.scatterplot(data=org_cars,x='Driving Range (km)',y='Battery Warranty (km)',c=org_cars['Labels'])
plt.title("Cluster plot")
# Out:
# Text(0.5, 1.0, 'Cluster plot')

# %%
label0_cars=org_cars[org_cars['Labels']==0]
label1_cars=org_cars[org_cars['Labels']==1]

# %%
label0_cars.describe()
# Out:
#        Driving Range (km)  Seating Capacity  NCAP Rating (Best - 5 Star)  \
# count            6.000000          6.000000                     6.000000
# mean           294.166667          4.666667                     1.666667
# std             53.983022          0.516398                     0.816497
# min            230.000000          4.000000                     0.000000
# 25%            255.000000          4.250000                     2.000000
# 50%            292.500000          5.000000                     2.000000
# 75%            322.500000          5.000000                     2.000000
# max            375.000000          5.000000                     2.000000
#
#        Battery Capacity          Size  Ground Clearance (mm)  \
# count          6.000000  6.000000e+00               6.000000
# mean          26.433333  1.028801e+10             178.666667
# std            7.121985  1.839682e+09              23.200575
# min           17.300000  7.340427e+09             146.000000
# ...

# %%
label1_cars.describe()
# Out:
#        Driving Range (km)  Seating Capacity  NCAP Rating (Best - 5 Star)  \
# count           14.000000         14.000000                    14.000000
# mean           503.500000          4.928571                     1.428571
# std            103.970225          0.267261                     0.513553
# min            302.000000          4.000000                     1.000000
# 25%            463.250000          5.000000                     1.000000
# 50%            496.500000          5.000000                     1.000000
# 75%            530.000000          5.000000                     2.000000
# max            708.000000          5.000000                     2.000000
#
#        Battery Capacity          Size  Ground Clearance (mm)  \
# count         14.000000  1.400000e+01              14.000000
# mean          76.958571  1.425631e+10             158.428571
# std           15.353852  1.341716e+09              19.081664
# min           50.300000  1.282655e+10             125.000000
# ...

# %%
label0_cars
# Out:
#                Name Fuel Type  Driving Range (km)  Seating Capacity  \
# 0     Tata Punch EV  Electric                 315                 5
# 1       MG Comet EV  Electric                 230                 4
# 2     Tata Nexon EV  Electric                 325                 5
# 3     Tata Tiago EV  Electric                 250                 5
# 5   Mahindra XUV400  Electric                 375                 5
# 16   MINI Cooper SE  Electric                 270                 4
#
#     NCAP Rating (Best - 5 Star)  Battery Capacity         Size  \
# 0                             2              25.0  10971953902
# 1                             2              17.3   7340426800
# 2                             2              30.0  11688744544
# 3                             0              19.2   9708461568
# 5                             2              34.5  12497158800
# 16                            2              32.6   9521296400
#
# ...
