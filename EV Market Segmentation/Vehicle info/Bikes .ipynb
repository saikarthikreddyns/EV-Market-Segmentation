# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df_bikes=pd.read_csv("ev_model_spec (1).csv")
df_bikes['Brand']=df_bikes['Model Name'].apply(lambda x:x.split(' ')[0])
df_bikes
# Out:
#                  Model Name   Price  Riding Range (km)  Top Speed (kmph)  \
# 0          Ampere Magnus EX  104758                121                53
# 1         Ampere Magnus Pro   66053                 45                25
# 2                Ampere REO   61993                 45                25
# 3               Ampere Zeal   96544                120                53
# 4                Ather 450X  135489                111                90
# 5              Bajaj Chetak  131196                 90                63
# 6              Benling Aura   91667                120                60
# 7                 BGauss B8   62999                 70                50
# 8        Bounce Infinity E1  100905                 85                65
# 9            e-bike Gen Nxt   74273                 60                25
# 10              Evolet Polo   55799                 90                25
# 11      Gemopai Astrid Lite   92289                 90                65
# ...

# %%
org_bikes=df_bikes.copy()

# %%
df_bikes
# Out:
#                  Model Name   Price  Riding Range (km)  Top Speed (kmph)  \
# 0          Ampere Magnus EX  104758                121                53
# 1         Ampere Magnus Pro   66053                 45                25
# 2                Ampere REO   61993                 45                25
# 3               Ampere Zeal   96544                120                53
# 4                Ather 450X  135489                111                90
# 5              Bajaj Chetak  131196                 90                63
# 6              Benling Aura   91667                120                60
# 7                 BGauss B8   62999                 70                50
# 8        Bounce Infinity E1  100905                 85                65
# 9            e-bike Gen Nxt   74273                 60                25
# 10              Evolet Polo   55799                 90                25
# 11      Gemopai Astrid Lite   92289                 90                65
# ...

# %%
df_bikes.isnull().sum()
brands=list(df_bikes['Brand'].unique())

# %%
df_bikes.duplicated().sum()
# Out:
# 0

# %%
df_bikes['Brand'] = df_bikes['Brand'].astype('category').cat.codes
df_bikes['Model Name'] = df_bikes['Model Name'].astype('category').cat.codes

# %%
df_bikes
# Out:
#     Model Name   Price  Riding Range (km)  Top Speed (kmph)  Weight (kg)  \
# 0            0  104758                121                53           90
# 1            1   66053                 45                25           94
# 2            2   61993                 45                25           88
# 3            3   96544                120                53           80
# 4            4  135489                111                90          108
# 5            6  131196                 90                63          133
# 6            7   91667                120                60           66
# 7            5   62999                 70                50           99
# 8            8  100905                 85                65           94
# 9           38   74273                 60                25           67
# 10           9   55799                 90                25           76
# 11          10   92289                 90                65           95
# ...

# %%
df_bikes['Brand']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
# 5      3
# 6      4
# 7      2
# 8      5
# 9     19
# 10     6
# 11     7
# 12     7
# 13     8
# 14     8
# 15     8
# 16     8
# 17     8
# 18     8
# 19     8
# 20     9
# 21     9
# 22    11
# 23    12
# 24    12
# 25    12
# 26    12
# 27    12
# 28    10
# 29    10
# 30    13
# 31    13
# 32    14
# 33    14
# 34    16
# 35    16
# 36    17
# 37    15
# 38    18
# Name: Brand, dtype: int8

# %%
df_bikes.dtypes
# Out:
# Model Name                      int8
# Price                          int64
# Riding Range (km)              int64
# Top Speed (kmph)               int64
# Weight (kg)                    int64
# Battery Charging Time (hrs)    int64
# Rated Power (W)                int64
# Brand                           int8
# dtype: object

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate (df_bikes.columns):
  if df_bikes[col].dtype != 'object':
    ax = plt.subplot(7, 2, i+1)
    sns.kdeplot(df_bikes[col], ax=ax)
    plt.xlabel(col)
    
plt.show()

# %%
a=np.arange(1,40)
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y=a,data=df_bikes)
plt.grid(axis='y')
plt.title('Brands in the datset')
plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Price',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Price')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Riding Range (km)',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Riding Range')
plt.xlabel('Brand')
plt.ylabel('Riding Range')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Top Speed (kmph)',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Top speed')
plt.xlabel('Brand')
plt.ylabel('Top speed')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Weight (kg)',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Weight (kg)')
plt.xlabel('Brand')
plt.ylabel('Weight (kg)')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Battery Charging Time (hrs)',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Battery Charging Time (hrs)')
plt.xlabel('Brand')
plt.ylabel('Battery Charging Time (hrs)')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
ax= plt.figure(figsize=(20,5))
sns.barplot(x='Brand',y='Rated Power (W)',data=df_bikes,palette='husl')
plt.grid(axis='y')
plt.title('Rated Power (W)')
plt.xlabel('Brand')
plt.ylabel('Rated Power (W)')
plt.xticks(ticks=np.arange(0, 20), labels=brands, rotation=45)
plt.show()

# %%
sns.heatmap(df_bikes.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df_bikes)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhoute_scores=[]
for i in range(2, 11):
    kmeans = KMeans(n_clusters = i, random_state = 42)
    kmeans.fit(df_bikes)
    silhoute_scores.append(silhouette_score(df_bikes,kmeans.labels_))

# %%
silhoute_scores
# Out:
# [0.5824379675323356,
#  0.5885498271878666,
#  0.6263644117198869,
#  0.5927155646829282,
#  0.5862704014590375,
#  0.5840015392171314,
#  0.5473526475672033,
#  0.5557484787953395,
#  0.5535082130128922]

# %% [markdown]
# # 3 is the optimal number of clusters

# %%
kmeans=KMeans(n_clusters=3,random_state=42)
kmeans.fit(df_bikes)

# %%
org_bikes['clusters']=kmeans.labels_

# %%
sns.scatterplot(data=df_bikes,x='Price',y='Riding Range (km)',c=org_bikes['clusters'])
# Out:
# <Axes: xlabel='Price', ylabel='Riding Range (km)'>

# %%
sns.scatterplot(data=df_bikes,x='Price',y='Top Speed (kmph)',c=org_bikes['clusters'])
# Out:
# <Axes: xlabel='Price', ylabel='Top Speed (kmph)'>

# %%
sns.scatterplot(data=df_bikes,x='Price',y='Weight (kg)',c=org_bikes['clusters'])
# Out:
# <Axes: xlabel='Price', ylabel='Weight (kg)'>

# %%
sns.scatterplot(data=df_bikes,x='Price',y='Battery Charging Time (hrs)',c=org_bikes['clusters'])
# Out:
# <Axes: xlabel='Price', ylabel='Battery Charging Time (hrs)'>

# %%
sns.scatterplot(data=df_bikes,x='Price',y='Rated Power (W)',c=org_bikes['clusters'])
# Out:
# <Axes: xlabel='Price', ylabel='Rated Power (W)'>

# %%
cluster0_bikes=org_bikes[org_bikes['clusters']==0]
cluster1_bikes=org_bikes[org_bikes['clusters']==1]
cluster2_bikes=org_bikes[org_bikes['clusters']==2]

# %%
cluster0_bikes.describe()
# Out:
#               Price  Riding Range (km)  Top Speed (kmph)  Weight (kg)  \
# count     16.000000          16.000000         16.000000    16.000000
# mean   66606.312500          72.750000         30.000000    89.000000
# std     8499.603612          20.124612         11.105554    32.555593
# min    51094.000000          45.000000         25.000000    59.000000
# 25%    61049.000000          60.000000         25.000000    67.000000
# 50%    66529.500000          65.000000         25.000000    78.000000
# 75%    73411.250000          86.250000         25.000000    95.250000
# max    78999.000000         120.000000         60.000000   150.000000
#
#        Battery Charging Time (hrs)  Rated Power (W)  clusters
# count                    16.000000        16.000000      16.0
# mean                      5.562500       396.875000       0.0
# std                       2.189939       348.553559       0.0
# min                       3.000000       250.000000       0.0
# ...

# %%
cluster1_bikes.describe()
# Out:
#                Price  Riding Range (km)  Top Speed (kmph)  Weight (kg)  \
# count       9.000000           9.000000          9.000000     9.000000
# mean   140352.333333         136.777778         81.111111   126.555556
# std     17727.562389          30.760274         17.273133    17.493650
# min    119827.000000          90.000000         58.000000   108.000000
# 25%    131196.000000         111.000000         70.000000   108.000000
# 50%    135489.000000         140.000000         80.000000   125.000000
# 75%    139828.000000         151.000000         90.000000   140.000000
# max    171250.000000         180.000000        116.000000   150.000000
#
#        Battery Charging Time (hrs)  Rated Power (W)  clusters
# count                     9.000000         9.000000       9.0
# mean                      5.888889      3222.222222       1.0
# std                       1.166667      1200.809912       0.0
# min                       5.000000      1000.000000       1.0
# ...

# %%
cluster2_bikes.describe()
# Out:
#                Price  Riding Range (km)  Top Speed (kmph)  Weight (kg)  \
# count      14.000000          14.000000         14.000000    14.000000
# mean    97637.142857         109.357143         52.071429    92.285714
# std      9152.990658          23.539189         11.377875    18.841152
# min     83897.000000          75.000000         25.000000    66.000000
# 25%     90628.250000          89.000000         45.750000    87.000000
# 50%     98522.000000         114.000000         53.000000    91.500000
# 75%    106244.500000         120.750000         60.000000    93.750000
# max    110376.000000         150.000000         65.000000   150.000000
#
#        Battery Charging Time (hrs)  Rated Power (W)  clusters
# count                    14.000000        14.000000      14.0
# mean                      4.928571      1275.000000       2.0
# std                       1.141139       619.165071       0.0
# min                       3.000000       250.000000       2.0
# ...
